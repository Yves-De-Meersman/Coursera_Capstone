# %% [markdown]
# # Capstone project week 5

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
import requests
from sklearn.cluster import KMeans

# %% [markdown]
# ## Gather the regions

# %%
df_flemish = pd.read_html("https://nl.wikipedia.org/wiki/Lijst_van_gemeenten_in_het_Vlaams_Gewest")[2]['Gemeente']
df_brussels = pd.read_html("https://nl.wikipedia.org/wiki/Lijst_van_gemeenten_in_het_Brussels_Hoofdstedelijk_Gewest")[0]['Gemeente']
df_walloon = pd.read_html("https://nl.wikipedia.org/wiki/Lijst_van_gemeenten_in_het_Waals_Gewest")[1]['Gemeente']

# %% [markdown]
# Explore the data

# %%
df_flemish.head()
# Out:
# 0         Aalst
# 1     Aalter[1]
# 2      Aarschot
# 3    Aartselaar
# 4      Affligem
# Name: Gemeente, dtype: object

# %%
df_brussels.head()
# Out:
# 0        Anderlecht
# 1    Brussel (stad)
# 2            Elsene
# 3         Etterbeek
# 4             Evere
# Name: Gemeente, dtype: object

# %%
df_walloon.head()
# Out:
# 0    's-Gravenbrakel (Braine-le-Comte)
# 1                       Aarlen (Arlon)
# 2                            Aat (Ath)
# 3                       Aiseau-Presles
# 4                                 Amay
# Name: Gemeente, dtype: object

# %%
mergedlist = []
mergedlist.extend(df_flemish)
mergedlist.extend(df_brussels)
mergedlist.extend(df_walloon)

# %% [markdown]
# Note: due to limitations of foursquare API, we only check the regions in Walloon.

# %% [markdown]
# ## Find coordinates for each region

# %%
from geopy.geocoders import Nominatim
def get_location(region):
    geolocator = Nominatim(user_agent="Coursera Capstone")
    location = geolocator.geocode(region + ", Belgium")
    print('Coordinates found of  '+ region)
    return [location.latitude, location.longitude]

# %% [markdown]
# Prepare data for coordinates extraction

# %%
df = pd.DataFrame(df_walloon) 
df.columns = ['Region']
df.drop(df[df.Region.str.contains('[1]')].index,inplace=True)

# %% [markdown]
# Use function to extract all coordinates

# %%
df['Coordinates'] = df['Region'].apply(get_location)
# Out:
# Coordinates found of  's-Gravenbrakel (Braine-le-Comte)
# Coordinates found of  Aarlen (Arlon)
# Coordinates found of  Aat (Ath)
# Coordinates found of  Aiseau-Presles
# Coordinates found of  Amay
# Coordinates found of  Amel
# Coordinates found of  Andenne
# Coordinates found of  Anderlues
# Coordinates found of  Anhée
# Coordinates found of  Ans
# Coordinates found of  Anthisnes
# Coordinates found of  Antoing
# Coordinates found of  Assesse
# Coordinates found of  Attert
# Coordinates found of  Aubange
# Coordinates found of  Aubel
# Coordinates found of  Awans
# Coordinates found of  Aywaille
# Coordinates found of  Baelen
# Coordinates found of  Bastenaken (Bastogne)
# Coordinates found of  Beaumont
# Coordinates found of  Beauraing
# Coordinates found of  Belœil
# Coordinates found of  Bergen (Mons)
# Coordinates found of  Berloz
# Coordinates found of  Bernissart
# Coordinates found of  Bertogne
# Coordinates found of  Bertrix
# Coordinates found of  Bevekom (Beauvechain)
# Coordinates found of  Beyne-Heusay
# Coordinates found of  Bièvre
# Coordinates found of  Binche
# Coordinates found of  Bitsingen (Bassenge)
# Coordinates found of  Blegny
# Coordinates found of  Blieberg (Plombières)
# Coordinates found of  Borgworm (Waremme)
# Coordinates found of  Bouillon
# Coordinates found of  Boussu
# Coordinates found of  Braives
# Coordinates found of  Brugelette
# Coordinates found of  Büllingen
# Coordinates found of  Brunehaut
# Coordinates found of  Burdinne
# Coordinates found of  Burg-Reuland
# Coordinates found of  Bütgenbach
# Coordinates found of  Celles
# Coordinates found of  Cerfontaine
# Coordinates found of  Chapelle-lez-Herlaimont
# Coordinates found of  Charleroi
# Coordinates found of  Chastre
# Coordinates found of  Châtelet
# Coordinates found of  Chaudfontaine
# Coordinates found of  Chaumont-Gistoux
# Coordinates found of  Chièvres
# Coordinates found of  Chimay
# Coordinates found of  Chiny
# Coordinates found of  Ciney
# Coordinates found of  Clavier
# Coordinates found of  Colfontaine
# Coordinates found of  Comblain-au-Pont
# Coordinates found of  Courcelles
# Coordinates found of  Court-Saint-Étienne
# Coordinates found of  Couvin
# Coordinates found of  Crisnée
# Coordinates found of  Dalhem
# Coordinates found of  Daverdisse
# Coordinates found of  Dinant
# Coordinates found of  Dison
# Coordinates found of  Doische
# Coordinates found of  Donceel
# Coordinates found of  Doornik (Tournai)
# Coordinates found of  Dour
# Coordinates found of  Durbuy
# Coordinates found of  Écaussinnes
# Coordinates found of  Edingen (Enghien)
# Coordinates found of  Eigenbrakel (Braine-l'Alleud)
# Coordinates found of  Éghezée
# Coordinates found of  Elzele (Ellezelles)
# Coordinates found of  Engis
# Coordinates found of  Érezée
# Coordinates found of  Erquelinnes
# Coordinates found of  Esneux
# Coordinates found of  Estinnes
# Coordinates found of  Étalle
# Coordinates found of  Eupen
# Coordinates found of  Faimes
# Coordinates found of  Farciennes
# Coordinates found of  Fauvillers
# Coordinates found of  Fernelmont
# Coordinates found of  Ferrières
# Coordinates found of  Fexhe-le-Haut-Clocher
# Coordinates found of  Flémalle
# Coordinates found of  Fléron
# Coordinates found of  Fleurus
# Coordinates found of  Floreffe
# Coordinates found of  Florennes
# Coordinates found of  Florenville
# Coordinates found of  Fontaine-l'Évêque
# Coordinates found of  Fosses-la-Ville
# Coordinates found of  Frameries
# Coordinates found of  Frasnes-lez-Anvaing
# Coordinates found of  Froidchapelle
# Coordinates found of  Gedinne
# Coordinates found of  Graven (Grez-Doiceau)
# Coordinates found of  Geer
# Coordinates found of  Geldenaken (Jodoigne)
# Coordinates found of  Gembloers (Gembloux)
# Coordinates found of  Genepiën (Genappe)
# Coordinates found of  Gerpinnes
# Coordinates found of  Gesves
# Coordinates found of  Gouvy
# Coordinates found of  Grâce-Hollogne
# Coordinates found of  Habay
# Coordinates found of  Hamoir
# Coordinates found of  Hamois
# Coordinates found of  Ham-sur-Heure-Nalinnes
# Coordinates found of  Hannuit (Hannut)
# Coordinates found of  Hastière
# Coordinates found of  Havelange
# Coordinates found of  Hélécine
# Coordinates found of  Hensies
# Coordinates found of  Herbeumont
# Coordinates found of  Héron
# Coordinates found of  Herstal
# Coordinates found of  Herve
# Coordinates found of  Honnelles
# Coordinates found of  Hotton
# Coordinates found of  Houffalize
# Coordinates found of  Houyet
# Coordinates found of  Hoei (Huy)
# Coordinates found of  Incourt
# Coordinates found of  Itter (Ittre)
# Coordinates found of  Jalhay
# Coordinates found of  Jemeppe-sur-Sambre
# Coordinates found of  Juprelle
# Coordinates found of  Jurbeke (Jurbise)
# Coordinates found of  Kasteelbrakel (Braine-le-Château)
# Coordinates found of  Kelmis
# Coordinates found of  Komen-Waasten (Comines-Warneton)
# Coordinates found of  La Bruyère
# Coordinates found of  La Louvière
# Coordinates found of  La Roche-en-Ardenne
# Coordinates found of  Lasne
# Coordinates found of  Léglise
# Coordinates found of  Lens
# Coordinates found of  Le Rœulx
# Coordinates found of  Les Bons Villers
# Coordinates found of  Lessen (Lessines)
# Coordinates found of  Leuze-en-Hainaut
# Coordinates found of  Libin
# Coordinates found of  Libramont-Chevigny
# Coordinates found of  Lierneux
# Coordinates found of  Limburg (Limbourg)
# Coordinates found of  Lijsem (Lincent)
# Coordinates found of  Lobbes
# Coordinates found of  Lontzen
# Coordinates found of  Luik (Liège)
# Coordinates found of  Malmedy
# Coordinates found of  Manage
# Coordinates found of  Manhay
# Coordinates found of  Marche-en-Famenne
# Coordinates found of  Marchin
# Coordinates found of  Martelange
# Coordinates found of  Meix-devant-Virton
# Coordinates found of  Merbes-le-Château
# Coordinates found of  Messancy
# Coordinates found of  Mettet
# Coordinates found of  Modave
# Coordinates found of  Moeskroen (Mouscron)
# Coordinates found of  Momignies
# Coordinates found of  Mont-de-l'Enclus
# Coordinates found of  Montigny-le-Tilleul
# Coordinates found of  Mont-Saint-Guibert
# Coordinates found of  Morlanwelz
# Coordinates found of  Musson
# Coordinates found of  Namen (Namur)
# Coordinates found of  Nandrin
# Coordinates found of  Nassogne
# Coordinates found of  Neufchâteau
# Coordinates found of  Neupré
# Coordinates found of  Nijvel (Nivelles)
# Coordinates found of  Oerle (Oreye)
# Coordinates found of  Ohey
# Coordinates found of  Olne
# Coordinates found of  Onhaye
# Coordinates found of  Opzullik (Silly)
# Coordinates found of  Orp-Jauche
# Coordinates found of  Ottignies-Louvain-la-Neuve
# Coordinates found of  Ouffet
# Coordinates found of  Oupeye
# Coordinates found of  Paliseul
# Coordinates found of  Pecq
# Coordinates found of  Pepinster
# Coordinates found of  Péruwelz
# Coordinates found of  Perwijs (Perwez)
# Coordinates found of  Philippeville
# Coordinates found of  Pont-à-Celles
# Coordinates found of  Profondeville
# Coordinates found of  Quaregnon
# Coordinates found of  Quévy
# Coordinates found of  Quiévrain
# Coordinates found of  Raeren
# Coordinates found of  Ramillies
# Coordinates found of  Rebecq
# Coordinates found of  Remicourt
# Coordinates found of  Rendeux
# Coordinates found of  Rixensart
# Coordinates found of  Rochefort
# Coordinates found of  Rouvroy
# Coordinates found of  Rumes
# Coordinates found of  Sainte-Ode
# Coordinates found of  Saint-Georges-sur-Meuse
# Coordinates found of  Saint-Ghislain
# Coordinates found of  Saint-Hubert
# Coordinates found of  Saint-Léger
# Coordinates found of  Saint-Nicolas
# Coordinates found of  Sankt Vith (Saint-Vith)
# Coordinates found of  Sambreville
# Coordinates found of  Seneffe
# Coordinates found of  Seraing
# Coordinates found of  Sivry-Rance
# Coordinates found of  Sombreffe
# Coordinates found of  Somme-Leuze
# Coordinates found of  Soumagne
# Coordinates found of  Spa
# Coordinates found of  Sprimont
# Coordinates found of  Stavelot
# Coordinates found of  Steenput (Estaimpuis)
# Coordinates found of  Stoumont
# Coordinates found of  Tellin
# Coordinates found of  Tenneville
# Coordinates found of  Terhulpen (La Hulpe)
# Coordinates found of  Theux
# Coordinates found of  Thimister-Clermont
# Coordinates found of  Thuin
# Coordinates found of  Tinlot
# Coordinates found of  Tintigny
# Coordinates found of  Trois-Ponts
# Coordinates found of  Trooz
# Coordinates found of  Tubeke (Tubize)
# Coordinates found of  Vaux-sur-Sûre
# Coordinates found of  Verlaine
# Coordinates found of  Verviers
# Coordinates found of  Vielsalm
# Coordinates found of  Villers-la-Ville
# Coordinates found of  Villers-le-Bouillet
# Coordinates found of  Viroinval
# Coordinates found of  Virton
# Coordinates found of  Vloesberg (Flobecq)
# Coordinates found of  Vresse-sur-Semois
# Coordinates found of  Walcourt
# Coordinates found of  Walhain
# Coordinates found of  Wanze
# Coordinates found of  Wasseiges
# Coordinates found of  Waterloo
# Coordinates found of  Waver (Wavre)
# Coordinates found of  Weismes (Waimes)
# Coordinates found of  Welkenraedt
# Coordinates found of  Wellin
# Coordinates found of  Wezet (Visé)
# Coordinates found of  Yvoir
# Coordinates found of  Zinnik (Soignies)

# %% [markdown]
# Backup the coordinates in a csv

# %%
df.to_csv('regions.csv')

# %%
df.Coordinates[0]
# Out:
# [50.6057582, 4.1382245]

# %%
df_coord = df.apply(lambda x: x['Coordinates'],axis=1,  result_type='expand')

# %%
df['Latitude'],df['Longitude']=df_coord[0],df_coord[1]

# %%
df = df.drop(columns=['Coordinates'])

# %%
df.head(35)
# Out:
#                                Region   Latitude  Longitude
# 0   's-Gravenbrakel (Braine-le-Comte)  50.605758   4.138224
# 1                      Aarlen (Arlon)  49.680415   5.809531
# 2                           Aat (Ath)  50.628868   3.785318
# 3                      Aiseau-Presles  50.416358   4.571198
# 4                                Amay  50.549776   5.324099
# 5                                Amel  50.354306   6.170556
# 6                             Andenne  50.489398   5.096547
# 7                           Anderlues  50.407997   4.269610
# 8                               Anhée  50.310151   4.877604
# 9                                 Ans  50.667986   5.507754
# 10                          Anthisnes  50.481662   5.522526
# 11                            Antoing  50.565955   3.451125
# 12                            Assesse  50.371826   5.021764
# 13                             Attert  49.751498   5.787222
# 14                            Aubange  49.567195   5.804499
# 15                              Aubel  50.704150   5.858555
# 16                              Awans  50.666971   5.462002
# 17                           Aywaille  50.475900   5.676325
# 18                             Baelen  50.631285   5.971347
# 19              Bastenaken (Bastogne)  50.862609   4.316650
# 20                           Beaumont  50.235529   4.238312
# 21                          Beauraing  50.110197   4.956740
# 22                             Belœil  50.547920   3.736128
# 23                      Bergen (Mons)  50.454088   3.941853
# 24                             Berloz  50.697842   5.214016
# 25                         Bernissart  50.475502   3.650468
# 26                           Bertogne  50.084291   5.667558
# 27                            Bertrix  49.854656   5.252927
# 28              Bevekom (Beauvechain)  50.780898   4.771730
# 29                       Beyne-Heusay  50.622057   5.653414
# 30                             Bièvre  49.941122   5.016850
# 31                             Binche  50.410300   4.165163
# 32               Bitsingen (Bassenge)  50.758360   5.609477
# 33                             Blegny  50.672719   5.725237
# 34              Blieberg (Plombières)  50.737732   5.961113

# %% [markdown]
# ## Find ventures for each region

# %%
CLIENT_ID = 'LVU42VHN3L144RFPJHP0XDDZ1U4YZEOMSJ2HQBVVRCSWG0JD' # your Foursquare ID
CLIENT_SECRET = '5GVZIN0N1MCQPNY1BGRFYGXJP3DWM1FJSXFGNOATFZN5U5K5' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: LVU42VHN3L144RFPJHP0XDDZ1U4YZEOMSJ2HQBVVRCSWG0JD
# CLIENT_SECRET:5GVZIN0N1MCQPNY1BGRFYGXJP3DWM1FJSXFGNOATFZN5U5K5

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=20000):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        cat = '4bf58dd8d48988d165941735,4bf58dd8d48988d1f8931735'   #Search for scenic lookouts and bed and breakfasts
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
            cat)  
        # make the GET request
        
        while True:
            try:
                returnjson = requests.get(url).json()
                results = returnjson["response"]['groups'][0]['items']
            except:
                print(returnjson)
                continue
            break
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    return(nearby_venues)

# %%
venues = getNearbyVenues(df['Region'],df['Latitude'],df['Longitude'])

# %% [markdown]
# Backup the venue list

# %%
venues.to_csv('venues.csv')

# %%
venues.head(20)
# Out:
#                          Neighborhood  Neighborhood Latitude  \
# 0   's-Gravenbrakel (Braine-le-Comte)              50.605758
# 1   's-Gravenbrakel (Braine-le-Comte)              50.605758
# 2   's-Gravenbrakel (Braine-le-Comte)              50.605758
# 3   's-Gravenbrakel (Braine-le-Comte)              50.605758
# 4   's-Gravenbrakel (Braine-le-Comte)              50.605758
# 5   's-Gravenbrakel (Braine-le-Comte)              50.605758
# 6   's-Gravenbrakel (Braine-le-Comte)              50.605758
# 7   's-Gravenbrakel (Braine-le-Comte)              50.605758
# 8   's-Gravenbrakel (Braine-le-Comte)              50.605758
# 9   's-Gravenbrakel (Braine-le-Comte)              50.605758
# 10  's-Gravenbrakel (Braine-le-Comte)              50.605758
# 11  's-Gravenbrakel (Braine-le-Comte)              50.605758
# 12  's-Gravenbrakel (Braine-le-Comte)              50.605758
# 13  's-Gravenbrakel (Braine-le-Comte)              50.605758
# 14  's-Gravenbrakel (Braine-le-Comte)              50.605758
# 15  's-Gravenbrakel (Braine-le-Comte)              50.605758
# 16  's-Gravenbrakel (Braine-le-Comte)              50.605758
# 17                     Aarlen (Arlon)              49.680415
# 18                     Aarlen (Arlon)              49.680415
# 19                          Aat (Ath)              50.628868
#
#     Neighborhood Longitude                          Venue  Venue Latitude  \
# 0                 4.138224              hof te spieringen       50.754791
# 1                 4.138224  Zevenbronnen - Sept Fontaines       50.734512
# 2                 4.138224         Petit Train du Bonheur       50.661057
# 3                 4.138224       Bed & Breakfast Wisteria       50.725606
# 4                 4.138224                          KUBUS       50.732236
# 5                 4.138224                    B&B Kaai 16       50.733389
# 6                 4.138224                 Villa D'Elbeek       50.744133
# 7                 4.138224                      Boesmolen       50.735248
# 8                 4.138224               Shelter Studio’s       50.750910
# 9                 4.138224           Belvédère des Bisons       50.583618
# 10                4.138224                     Bruine Put       50.736640
# 11                4.138224          Sint-Martinusbasiliek       50.736675
# 12                4.138224            Rigaux 1878 Gasthof       50.717793
# 13                4.138224                 Hof Ter Haegen       50.757045
# 14                4.138224                 Hof ter Wilgen       50.733866
# 15                4.138224                    Haumautveld       50.718339
# 16                4.138224                   Pelikaanberg       50.771688
# 17                5.809531          Chateau de Hollenfels       49.712293
# 18                5.809531                   Relax & Cook       49.611384
# 19                3.785318                  Hakuna Matata       50.762062
#
#     Venue Longitude   Venue Category
# 0          4.045691  Bed & Breakfast
# 1          4.335727   Scenic Lookout
# 2          4.134471   Scenic Lookout
# 3          4.019616  Bed & Breakfast
# 4          4.036421   Scenic Lookout
# 5          4.239344  Bed & Breakfast
# 6          4.200810  Bed & Breakfast
# 7          4.026112   Scenic Lookout
# 8          4.258561  Bed & Breakfast
# 9          3.882122   Scenic Lookout
# 10         4.295384   Scenic Lookout
# 11         4.237410           Church
# 12         3.942958  Bed & Breakfast
# 13         4.008633  Bed & Breakfast
# 14         3.939470  Bed & Breakfast
# 15         3.952220             Farm
# 16         4.188224   Scenic Lookout
# 17         6.050951   Scenic Lookout
# 18         5.817693  Bed & Breakfast
# 19         3.925631  Bed & Breakfast

# %%
venues_filtered = venues[(venues['Venue Category']=='Scenic Lookout') | (venues['Venue Category']=='Bed & Breakfast')]

# %% [markdown]
# Check what was returned for each region

# %%
venues_filtered.groupby(['Neighborhood','Venue Category']).count()
# Out:
#                                                    Neighborhood Latitude  \
# Neighborhood                      Venue Category
# 's-Gravenbrakel (Braine-le-Comte) Bed & Breakfast                      8
#                                   Scenic Lookout                       7
# Aarlen (Arlon)                    Bed & Breakfast                      1
#                                   Scenic Lookout                       1
# Aat (Ath)                         Bed & Breakfast                     15
# ...                                                                  ...
# Éghezée                           Bed & Breakfast                      4
#                                   Scenic Lookout                       4
# Érezée                            Bed & Breakfast                     22
#                                   Scenic Lookout                      10
# Étalle                            Bed & Breakfast                      2
#
#                                                    Neighborhood Longitude  \
# Neighborhood                      Venue Category
# 's-Gravenbrakel (Braine-le-Comte) Bed & Breakfast                       8
#                                   Scenic Lookout                        7
# Aarlen (Arlon)                    Bed & Breakfast                       1
#                                   Scenic Lookout                        1
# Aat (Ath)                         Bed & Breakfast                      15
# ...                                                                   ...
# Éghezée                           Bed & Breakfast                       4
#                                   Scenic Lookout                        4
# Érezée                            Bed & Breakfast                      22
#                                   Scenic Lookout                       10
# Étalle                            Bed & Breakfast                       2
#
#                                                    Venue  Venue Latitude  \
# Neighborhood                      Venue Category
# 's-Gravenbrakel (Braine-le-Comte) Bed & Breakfast      8               8
#                                   Scenic Lookout       7               7
# Aarlen (Arlon)                    Bed & Breakfast      1               1
#                                   Scenic Lookout       1               1
# Aat (Ath)                         Bed & Breakfast     15              15
# ...                                                  ...             ...
# Éghezée                           Bed & Breakfast      4               4
#                                   Scenic Lookout       4               4
# Érezée                            Bed & Breakfast     22              22
#                                   Scenic Lookout      10              10
# Étalle                            Bed & Breakfast      2               2
#
#                                                    Venue Longitude
# Neighborhood                      Venue Category
# 's-Gravenbrakel (Braine-le-Comte) Bed & Breakfast                8
#                                   Scenic Lookout                 7
# Aarlen (Arlon)                    Bed & Breakfast                1
#                                   Scenic Lookout                 1
# Aat (Ath)                         Bed & Breakfast               15
# ...                                                            ...
# Éghezée                           Bed & Breakfast                4
#                                   Scenic Lookout                 4
# Érezée                            Bed & Breakfast               22
#                                   Scenic Lookout                10
# Étalle                            Bed & Breakfast                2
#
# [485 rows x 5 columns]

# %% [markdown]
# One hot encoding

# %%
# one hot encoding
onehot = pd.get_dummies(venues_filtered[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
onehot['Neighborhood'] = venues_filtered['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [onehot.columns[-1]] + list(onehot.columns[:-1])
onehot = onehot[fixed_columns]

onehot.head()
# Out:
#                         Neighborhood  Bed & Breakfast  Scenic Lookout
# 0  's-Gravenbrakel (Braine-le-Comte)                1               0
# 1  's-Gravenbrakel (Braine-le-Comte)                0               1
# 2  's-Gravenbrakel (Braine-le-Comte)                0               1
# 3  's-Gravenbrakel (Braine-le-Comte)                1               0
# 4  's-Gravenbrakel (Braine-le-Comte)                0               1

# %% [markdown]
# Group them together

# %%
grouped = onehot.groupby('Neighborhood').sum().reset_index()
grouped.columns= ['Region','Bed & Breakfast', 'Scenic Lookout']

# %%
grouped.Regio
# Out:
# 0      's-Gravenbrakel (Braine-le-Comte)
# 1                         Aarlen (Arlon)
# 2                              Aat (Ath)
# 3                         Aiseau-Presles
# 4                                   Amay
#                      ...
# 254                    Zinnik (Soignies)
# 255                          Écaussinnes
# 256                              Éghezée
# 257                               Érezée
# 258                               Étalle
# Name: Region, Length: 259, dtype: object

# %%
merged = df.merge(grouped,on='Region')

# %% [markdown]
# ## Analyze results

# %% [markdown]
# ### DBSCAN clusters

# %%
df_clustered = df.copy()

# %%
from sklearn.cluster import DBSCAN
import sklearn.utils
from sklearn.preprocessing import StandardScaler
sklearn.utils.check_random_state(1000)
Clus_dataSet = df_clustered[['Latitude','Longitude']]
Clus_dataSet = np.nan_to_num(Clus_dataSet)
Clus_dataSet = StandardScaler().fit_transform(Clus_dataSet)

# Compute DBSCAN
db = DBSCAN(eps=0.5, min_samples=100).fit(Clus_dataSet)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
df_clustered["Clus_Db"]=labels

realClusterNum=len(set(labels)) - (1 if -1 in labels else 0)
clusterNum = len(set(labels)) 


# A sample of clusters
df_clustered[["Region","Latitude","Longitude","Clus_Db"]].head()
# Out:
#                               Region   Latitude  Longitude  Clus_Db
# 0  's-Gravenbrakel (Braine-le-Comte)  50.605758   4.138224       -1
# 1                     Aarlen (Arlon)  49.680415   5.809531       -1
# 2                          Aat (Ath)  50.628868   3.785318       -1
# 3                     Aiseau-Presles  50.416358   4.571198       -1
# 4                               Amay  50.549776   5.324099       -1

# %% [markdown]
# DBSCAN on location and Scenic Lookout and BnB

# %%
from sklearn.cluster import DBSCAN
import sklearn.utils
from sklearn.preprocessing import StandardScaler
merged_clustered = merged.copy()
sklearn.utils.check_random_state(1000)
Clus_dataSet = merged_clustered[['Latitude','Longitude','Scenic Lookout','Bed & Breakfast']]
Clus_dataSet = np.nan_to_num(Clus_dataSet)
Clus_dataSet = StandardScaler().fit_transform(Clus_dataSet)

# Compute DBSCAN
db = DBSCAN(eps=0.2, min_samples=5).fit(Clus_dataSet)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
merged_clustered["Clus_Db"]=labels

realClusterNum=len(set(labels)) - (1 if -1 in labels else 0)
clusterNum = len(set(labels)) 


# A sample of clusters
merged_clustered[['Latitude','Longitude','Scenic Lookout','Bed & Breakfast',"Clus_Db"]].head(5)
# Out:
#     Latitude  Longitude  Scenic Lookout  Bed & Breakfast  Clus_Db
# 0  50.605758   4.138224               7                8       -1
# 1  49.680415   5.809531               1                1       -1
# 2  50.628868   3.785318               6               15       -1
# 3  50.416358   4.571198               0                1       -1
# 4  50.549776   5.324099               1                3       -1

# %%
set(labels)
# Out:
# {-1, 0, 1}

# %% [markdown]
# ## K means clustering

# %%
df_clustered = merged.copy()

# %%
# set number of clusters
kclusters = 100

df_clustering = df_clustered.drop('Region', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([63, 96, 88, 44, 22, 34, 59,  1, 68,  8])

# %%
# add clustering labels 
merged.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
merged[merged['Cluster Labels']==47]
# Out:
#      Cluster Labels    Region   Latitude  Longitude  Bed & Breakfast  \
# 131              47    Jalhay  50.559253   5.964753               16
# 222              47       Spa  50.492084   5.862623               17
# 224              47  Stavelot  50.394085   5.930836               17
#
#      Scenic Lookout
# 131              15
# 222              16
# 224              15

# %%
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
# create map
map_clusters = folium.Map(location=[49.680415, 5.809531], zoom_start=8)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(merged['Latitude'], merged['Longitude'], merged['Region'], merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Get the clusters with the least bed and breakfasts and the highest number of lookout points

# %%
grouped = merged.drop(columns='Region')

# %%
grouped = grouped.groupby(by='Cluster Labels').agg({'Latitude': 'mean','Longitude': 'mean','Bed & Breakfast':'sum' , 'Scenic Lookout': 'sum'})

# %%
grouped.head()
# Out:
#                  Latitude  Longitude  Bed & Breakfast  Scenic Lookout
# Cluster Labels
# 0               50.505291   5.431396               91              28
# 1               50.424191   4.270630               14              28
# 2               50.697278   4.047130               19              14
# 3               50.191315   5.118261               45              26
# 4               50.745651   3.511054               38              13

# %% [markdown]
# We are interested in regions where there are more scenic lookouts than bed and breakfasts

# %%
#Define a ratio factor
grouped['Ratio']=grouped['Scenic Lookout']/grouped['Bed & Breakfast']

# %%
sorted = grouped.sort_values(by=['Ratio'], ascending=False, axis=0)
sorted.head(20)
# Out:
#                  Latitude  Longitude  Bed & Breakfast  Scenic Lookout  \
# Cluster Labels
# 52              50.231717   4.313929                0               9
# 48              50.472442   4.696927                4              18
# 85              50.394374   4.261633                4              13
# 21              50.590719   4.571203                5              14
# 19              50.676130   6.110840                7              19
# 1               50.424191   4.270630               14              28
# 60              50.319766   5.293815               16              30
# 96              49.739695   5.473635                4               7
# 54              50.237363   4.217197                4               7
# 59              50.507538   4.606792               13              22
# 18              50.704150   5.858555               16              27
# 5               50.672719   5.725237               15              21
# 71              50.416319   4.728966               10              14
# 7               49.613436   5.656957                4               5
# 34              50.390516   6.187957               17              21
# 29              50.546974   4.843073               19              23
# 87              50.635223   4.329526               15              18
# 80              49.548577   5.597796                6               7
# 35              49.794984   5.067253                6               7
# 38              50.414913   6.111754               13              15
#
#                    Ratio
# Cluster Labels
# 52                   inf
# 48              4.500000
# 85              3.250000
# 21              2.800000
# 19              2.714286
# 1               2.000000
# 60              1.875000
# 96              1.750000
# 54              1.750000
# 59              1.692308
# 18              1.687500
# 5               1.400000
# 71              1.400000
# 7               1.250000
# 34              1.235294
# 29              1.210526
# 87              1.200000
# 80              1.166667
# 35              1.166667
# 38              1.153846

# %%
#Take out the most interesting ones, this means, a lot of scenic lookouts and a good ratio
filtered = sorted[((sorted.Ratio > 1.5)) & (sorted['Scenic Lookout']>15)].reset_index()

# %%
filtered
# Out:
#    Cluster Labels   Latitude  Longitude  Bed & Breakfast  Scenic Lookout  \
# 0              48  50.472442   4.696927                4              18
# 1              19  50.676130   6.110840                7              19
# 2               1  50.424191   4.270630               14              28
# 3              60  50.319766   5.293815               16              30
# 4              59  50.507538   4.606792               13              22
# 5              18  50.704150   5.858555               16              27
#
#       Ratio
# 0  4.500000
# 1  2.714286
# 2  2.000000
# 3  1.875000
# 4  1.692308
# 5  1.687500

# %% [markdown]
# Show the ideal locations on a map

# %%
# create map
map_clusters = folium.Map(location=[49.680415, 5.809531], zoom_start=8)

# set color scheme for the clusters
x = np.arange(filtered.Ratio.count())
ys = [i + x + (i*x)**2 for i in range(filtered.Ratio.count())]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, bnb,scenic, cluster in zip(filtered['Latitude'], filtered['Longitude'],filtered['Bed & Breakfast'],filtered['Scenic Lookout'], filtered['Cluster Labels'].index):
    label = folium.Popup('BNB: ' + str(bnb) + ' Scenic: ' + str(scenic), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
filtered.Ratio.count()
# Out:
# 6
